# %%
import mne.io as mio
import mne
import numpy as np
import pickle

# %% [markdown]
# # EDF 파일을 불러오기

# %%
n_normal = 71
n_osa = 229
n_test = 102
n_private_test = 100

# raw_ecg_normal = []
# for i in range (1, n_normal + 1):
#     temp = []
#     raw = mio.read_raw_edf("/home/maic-player/dataset/1_Train+Val/Normal_" + str(i).zfill(3) + ".edf")
#     raw_ecg_normal.append(raw)

# raw_ecg_osa = []
# for i in range (1, n_osa + 1):
#     temp = []
#     raw = mio.read_raw_edf("/home/maic-player/dataset/1_Train+Val/OSA_" + str(i).zfill(3) + ".edf")
#     raw_ecg_osa.append(raw)

raw_ecg_test = []
for i in range (1, n_test + 1):
    raw = mio.read_raw_edf("/home/maic-player/dataset/2_Test/Test_" + str(i).zfill(3) + ".edf")
    raw_ecg_test.append(raw)
    
#raw_ecg_private_test = []
#for i in range(103, 103 + n_private_test):
#    raw = mio.read_raw_edf("/home/maic-player/dataset/2_Test/Test_" + str(i).zfill(3) + ".edf")
#    raw_ecg_test.append(raw)
# Out:
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_022.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_028.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_029.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_032.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_034.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_035.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_036.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_037.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_038.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_039.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_040.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_041.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_042.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_043.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_044.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_045.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_046.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_047.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_048.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_049.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_050.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_051.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_052.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_053.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_054.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_055.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_056.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_057.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_058.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_059.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_060.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_061.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_062.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_063.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_064.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_065.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_066.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_067.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_068.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_069.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_070.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_071.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_072.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_073.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_074.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_075.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_076.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_077.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_078.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_079.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_080.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_081.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_082.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_083.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_084.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_085.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_086.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_087.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_088.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_089.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_090.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_091.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_092.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_093.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_094.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_095.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_096.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_097.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_098.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_099.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_100.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_101.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/2_Test/Test_102.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %% [markdown]
# # 30분 ~ 1시간으로 자르기

# %%
# for i in raw_ecg_normal:
#     i.crop(1800, 3600)
# for i in raw_ecg_osa:
#     i.crop(1800, 3600)
for i in raw_ecg_test:
    i.crop(1800, 3600)
    
#for i in raw_ecg_private_test:
#    i.crop(1800, 3600)

# %% [markdown]
# # ECG 데이터에서 피크가 발생한 프레임 찾기

# %%
low = 8
high = 16

# events_normal = []
# events_osa = []
events_test = []

# for i in raw_ecg_normal:
#     events_normal.append(mne.preprocessing.find_ecg_events(i, 
#                                                    ch_name="ECG",
#                                                    l_freq=low, h_freq=high,
#                                                    return_ecg=True))
# for i in raw_ecg_osa:
#     events_osa.append(mne.preprocessing.find_ecg_events(i, 
#                                                    ch_name="ECG",
#                                                    l_freq=low, h_freq=high,
#                                                    return_ecg=True))
for i in raw_ecg_test:
    events_test.append(mne.preprocessing.find_ecg_events(i, 
                                                    ch_name="ECG",
                                                    l_freq=low, h_freq=high,
                                                    return_ecg=True))
    
#events_private_test = []

#for i in raw_ecg_private_test:
#    events_private_test.append(mne.preprocessing.find_ecg_events(i, 
#                                                   ch_name="ECG",
#                                                   l_freq=low, h_freq=high,
#                                                   return_ecg=True))
# Out:
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
# /miniconda/envs/empty-maic2022/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Number of ECG events detected : 1842 (average pulse 61 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1687 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2990 (average pulse 99 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2116 (average pulse 70 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2724 (average pulse 90 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1892 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2935 (average pulse 97 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2576 (average pulse 85 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3021 (average pulse 100 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1914 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1751 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3331 (average pulse 111 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2451 (average pulse 81 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2287 (average pulse 76 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1803 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1869 (average pulse 62 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1700 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2553 (average pulse 85 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3093 (average pulse 103 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2396 (average pulse 79 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1721 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1934 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2483 (average pulse 82 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2336 (average pulse 77 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1581 (average pulse 52 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2084 (average pulse 69 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1947 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1964 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2266 (average pulse 75 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3092 (average pulse 103 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1991 (average pulse 66 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2549 (average pulse 84 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1673 (average pulse 55 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2753 (average pulse 91 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1813 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3365 (average pulse 112 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1509 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2797 (average pulse 93 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2412 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1988 (average pulse 66 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2678 (average pulse 89 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1524 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2185 (average pulse 72 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2219 (average pulse 73 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2626 (average pulse 87 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3039 (average pulse 101 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1823 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2085 (average pulse 69 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1946 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2414 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1737 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1983 (average pulse 66 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2194 (average pulse 73 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2619 (average pulse 87 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1979 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1400 (average pulse 46 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1644 (average pulse 54 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1550 (average pulse 51 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1845 (average pulse 61 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2547 (average pulse 84 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2076 (average pulse 69 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1764 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2762 (average pulse 92 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2205 (average pulse 73 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2964 (average pulse 98 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2053 (average pulse 68 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2743 (average pulse 91 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2200 (average pulse 73 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2259 (average pulse 75 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1943 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2514 (average pulse 83 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1903 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2419 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2756 (average pulse 91 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1961 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1732 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2726 (average pulse 90 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1832 (average pulse 61 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3398 (average pulse 113 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1930 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2893 (average pulse 96 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2057 (average pulse 68 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1623 (average pulse 54 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1841 (average pulse 61 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1949 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1875 (average pulse 62 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2323 (average pulse 77 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1532 (average pulse 51 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1967 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1903 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1512 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3214 (average pulse 107 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2300 (average pulse 76 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1431 (average pulse 47 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1689 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2257 (average pulse 75 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1729 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1980 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1943 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1919 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2484 (average pulse 82 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1911 (average pulse 63 / min.)

# %% [markdown]
# # pickle 로 찾은 프레임 값들을 저장하기

# %%
# with open("ecg_find_normal_30min", "wb") as f:
#     pickle.dump(events_normal, f)
# with open("ecg_find_osa_30min", "wb") as f:
#     pickle.dump(events_osa, f)
with open("Data/ecg_find_test_30min", "wb") as f:
    pickle.dump(events_test, f)
#with open("Data/ecg_find_private_test_30min", "wb") as f:
#    pickle.dump(events_private_test, f)
