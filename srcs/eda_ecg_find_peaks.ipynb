# %%
import mne.io as mio
import mne
import numpy as np
import pickle

# %% [markdown]
# # EDF 파일을 불러오기

# %%
n_normal = 71
n_osa = 229
n_test = 102
n_private_test = 100

# raw_ecg_normal = []
# for i in range (1, n_normal + 1):
#     temp = []
#     raw = mio.read_raw_edf("/home/maic-player/dataset/1_Train+Val/Normal_" + str(i).zfill(3) + ".edf")
#     raw_ecg_normal.append(raw)

# raw_ecg_osa = []
# for i in range (1, n_osa + 1):
#     temp = []
#     raw = mio.read_raw_edf("/home/maic-player/dataset/1_Train+Val/OSA_" + str(i).zfill(3) + ".edf")
#     raw_ecg_osa.append(raw)

# raw_ecg_test = []
# for i in range (1, n_test + 1):
#     temp = []
#     raw = mio.read_raw_edf("/home/maic-player/dataset/2_Test/Test_" + str(i).zfill(3) + ".edf")
#     raw_ecg_test.append(raw)
    
raw_ecg_private_test = []
for i in range(103, 103 + n_private_test):
    raw = mio.read_raw_edf("/home/maic-player/dataset/2_Test/Test_" + str(i).zfill(3) + ".edf")
    raw_ecg_test.append(raw)
# Out:
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_022.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_028.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_029.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_032.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_034.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_035.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_036.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_037.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_038.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_039.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_040.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_041.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_042.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_043.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_044.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_045.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_046.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_047.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_048.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_049.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_050.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_051.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_052.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_053.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_054.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_055.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_056.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_057.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_058.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_059.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_060.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_061.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_062.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_063.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_064.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_065.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_066.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_067.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_068.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_069.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_070.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/Normal_071.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_003.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_004.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_005.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_006.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_007.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_008.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_009.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_010.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_011.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_012.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_013.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_014.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_015.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_016.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_017.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_018.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_019.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_020.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_022.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_023.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_024.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_025.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_026.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_027.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_028.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_029.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_030.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_031.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_032.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_033.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_034.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_035.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_036.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_037.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_038.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_039.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_040.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_041.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_042.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_043.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_044.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_045.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_046.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_047.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_048.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_049.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_050.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_051.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_052.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_053.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_054.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_055.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_056.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_057.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_058.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_059.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_060.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_061.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_062.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_063.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_064.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_065.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_066.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_067.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_068.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_069.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_070.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_071.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_072.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_073.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_074.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_075.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_076.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_077.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_078.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_079.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_080.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_081.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_082.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_083.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_084.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_085.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_086.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_087.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_088.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_089.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_090.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_091.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_092.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_093.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_094.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_095.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_096.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_097.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_098.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_099.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_100.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_101.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_102.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_103.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_104.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_105.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_106.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_107.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_108.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_109.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_110.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_111.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_112.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_113.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_114.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_115.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_116.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_117.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_118.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_119.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_120.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_121.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_122.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_123.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_124.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_125.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_126.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_127.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_128.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_129.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_130.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_131.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_132.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_133.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_134.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_135.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_136.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_137.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_138.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_139.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_140.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_141.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_142.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_143.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_144.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_145.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_146.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_147.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_148.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_149.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_150.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_151.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_152.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_153.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_154.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_155.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_156.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_157.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_158.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_159.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_160.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_161.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_162.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_163.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_164.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_165.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_166.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_167.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_168.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_169.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_170.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_171.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_172.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_173.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_174.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_175.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_176.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_177.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_178.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_179.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_180.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_181.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_182.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_183.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_184.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_185.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_186.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_187.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_188.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_189.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_190.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_191.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_192.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_193.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_194.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_195.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_196.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_197.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_198.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_199.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_200.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_201.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_202.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_203.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_204.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_205.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_206.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_207.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_208.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_209.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_210.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /home/maic-player/dataset/1_Train+Val/OSA_211.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 14
#      12 for i in range (1, n_osa + 1):
#      13     temp = []
# ---> 14     raw = mio.read_raw_edf("/home/maic-player/dataset/1_Train+Val/OSA_" + str(i).zfill(3) + ".edf")
#      15     raw_ecg_osa.append(raw)
#      17 raw_ecg_test = []
#
# File /miniconda/envs/empty-maic2022/lib/python3.8/site-packages/mne/io/edf/edf.py:1412, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, verbose)
#    1410 if ext != 'edf':
#    1411     raise NotImplementedError(f'Only EDF files are supported, got {ext}.')
# -> 1412 return RawEDF(input_fname=input_fname, eog=eog, misc=misc,
#    1413               stim_channel=stim_channel, exclude=exclude,
#    1414               infer_types=infer_types, preload=preload, include=include,
#    1415               units=units, encoding=encoding, verbose=verbose)
#
# File <decorator-gen-246>:12, in __init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, verbose)
#
# File /miniconda/envs/empty-maic2022/lib/python3.8/site-packages/mne/io/edf/edf.py:186, in RawEDF.__init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, verbose)
#     178     tal_data = self._read_segment_file(
#     179         np.empty((0, self.n_times)), idx, 0, 0, int(self.n_times),
#     180         np.ones((len(idx), 1)), None)
#     181     onset, duration, desc = _read_annotations_edf(
#     182         tal_data[0],
#     183         encoding=encoding,
#     184     )
# --> 186 self.set_annotations(Annotations(onset=onset, duration=duration,
#     187                                  description=desc, orig_time=None))
#
# File <decorator-gen-228>:12, in set_annotations(self, annotations, emit_warning, on_missing, verbose)
#
# File /miniconda/envs/empty-maic2022/lib/python3.8/site-packages/mne/io/base.py:633, in BaseRaw.set_annotations(self, annotations, emit_warning, on_missing, verbose)
#     631 new_annotations._prune_ch_names(self.info, on_missing)
#     632 if annotations.orig_time is None:
# --> 633     new_annotations.crop(0, self.times[-1] + delta,
#     634                          emit_warning=emit_warning)
#     635     new_annotations.onset += self._first_time
#     636 else:
#
# File /miniconda/envs/empty-maic2022/lib/python3.8/site-packages/mne/io/base.py:1548, in BaseRaw.times(self)
#    1545 @property
#    1546 def times(self):
#    1547     """Time points."""
# -> 1548     out = _arange_div(self.n_times, float(self.info['sfreq']))
#    1549     out.flags['WRITEABLE'] = False
#    1550     return out
#
# File /miniconda/envs/empty-maic2022/lib/python3.8/site-packages/mne/utils/numerics.py:1097, in _arange_div_fallback(n, d)
#    1096 def _arange_div_fallback(n, d):
# -> 1097     x = np.arange(n, dtype=np.float64)
#    1098     x /= d
#    1099     return x
#
# KeyboardInterrupt:

# %% [markdown]
# # 30분 ~ 1시간으로 자르기

# %%
# for i in raw_ecg_normal:
#     i.crop(1800, 3600)
# for i in raw_ecg_osa:
#     i.crop(1800, 3600)
# for i in raw_ecg_test:
#     i.crop(1800, 3600)
    
for i in raw_ecg_private_test:
    i.crop(1800, 3600)

# %% [markdown]
# # ECG 데이터에서 피크가 발생한 프레임 찾기

# %%
low = 8
high = 16

# events_normal = []
# events_osa = []
# events_test = []

# for i in raw_ecg_normal:
#     events_normal.append(mne.preprocessing.find_ecg_events(i, 
#                                                    ch_name="ECG",
#                                                    l_freq=low, h_freq=high,
#                                                    return_ecg=True))
# for i in raw_ecg_osa:
#     events_osa.append(mne.preprocessing.find_ecg_events(i, 
#                                                    ch_name="ECG",
#                                                    l_freq=low, h_freq=high,
#                                                    return_ecg=True))
# for i in raw_ecg_test:
#     events_test.append(mne.preprocessing.find_ecg_events(i, 
#                                                    ch_name="ECG",
#                                                    l_freq=low, h_freq=high,
#                                                    return_ecg=True))
    
events_private_test = []

for i in raw_ecg_private_test:
    events_private_test.append(mne.preprocessing.find_ecg_events(i, 
                                                   ch_name="ECG",
                                                   l_freq=low, h_freq=high,
                                                   return_ecg=True))
# Out:
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3037 (average pulse 101 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1974 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1305 (average pulse 43 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1543 (average pulse 51 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2556 (average pulse 85 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1467 (average pulse 48 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2147 (average pulse 71 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1757 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1745 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1774 (average pulse 59 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1669 (average pulse 55 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2059 (average pulse 68 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3096 (average pulse 103 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2991 (average pulse 99 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2522 (average pulse 84 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1939 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1691 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1649 (average pulse 54 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2064 (average pulse 68 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2332 (average pulse 77 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1668 (average pulse 55 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2651 (average pulse 88 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2135 (average pulse 71 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2477 (average pulse 82 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1889 (average pulse 62 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2161 (average pulse 72 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2107 (average pulse 70 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1912 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2094 (average pulse 69 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1947 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2330 (average pulse 77 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1744 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2365 (average pulse 78 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1859 (average pulse 61 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1528 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1897 (average pulse 63 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1688 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2694 (average pulse 89 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1830 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1783 (average pulse 59 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3011 (average pulse 100 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2414 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2595 (average pulse 86 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2724 (average pulse 90 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1648 (average pulse 54 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2037 (average pulse 67 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1824 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2654 (average pulse 88 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1742 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2826 (average pulse 94 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1816 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1517 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2648 (average pulse 88 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1813 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2325 (average pulse 77 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1820 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1579 (average pulse 52 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3237 (average pulse 107 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1959 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1578 (average pulse 52 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1473 (average pulse 49 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1518 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2327 (average pulse 77 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2196 (average pulse 73 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2423 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2799 (average pulse 93 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2962 (average pulse 98 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2050 (average pulse 68 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2235 (average pulse 74 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1938 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1978 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1969 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1943 (average pulse 64 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2243 (average pulse 74 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2593 (average pulse 86 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1726 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2447 (average pulse 81 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2082 (average pulse 69 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2525 (average pulse 84 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2652 (average pulse 88 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# ...
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2842 (average pulse 94 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1823 (average pulse 60 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1964 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2108 (average pulse 70 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2186 (average pulse 72 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2164 (average pulse 72 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2410 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 3040 (average pulse 101 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1675 (average pulse 55 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1860 (average pulse 61 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2262 (average pulse 75 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1961 (average pulse 65 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1797 (average pulse 59 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1687 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1443 (average pulse 48 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2688 (average pulse 89 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2253 (average pulse 75 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1729 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2412 (average pulse 80 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2004 (average pulse 66 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1519 (average pulse 50 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1734 (average pulse 57 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2787 (average pulse 92 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1709 (average pulse 56 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 1760 (average pulse 58 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2754 (average pulse 91 / min.)
# Using channel ECG to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 2500 samples (10.000 sec)
#
# Number of ECG events detected : 2262 (average pulse 75 / min.)

# %% [markdown]
# # pickle 로 찾은 프레임 값들을 저장하기

# %%
# with open("ecg_find_normal_30min", "wb") as f:
#     pickle.dump(events_normal, f)
# with open("ecg_find_osa_30min", "wb") as f:
#     pickle.dump(events_osa, f)
# with open("ecg_find_test_30min", "wb") as f:
#     pickle.dump(events_test, f)
with open("Data/ecg_find_private_test_30min", "wb") as f:
    pickle.dump(events_private_test, f)
